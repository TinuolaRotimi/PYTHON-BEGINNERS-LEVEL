# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize']=6,2

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\user\Pictures\Downloads\13th\13th\DataFrame_ Pandas\data.csv')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1=sns.distplot(df['InternetUsers'])  #UNIVARIABLE ANALYSIS
plt.show()

# %%
vis2 = sns.distplot(df['InternetUsers'])
plt.show()

# %%
vis3=sns.distplot(df['InternetUsers'], bins=10)
plt.show()

# %%
vis3=sns.distplot(df['InternetUsers'], bins=25)
plt.show()

# %%
vis4=sns.boxplot(data=df,x='IncomeGroup',y='BirthRate') #BI-VARIATE ANALYSIS
plt.show(vis4)

# %% [markdown]
# # VISUALIZING WITH SEABORN

# %%
vis5=sns.lmplot(data=df,x='InternetUsers',y='BirthRate')
plt.show()

# %%
vis6=sns.lmplot(data=df,x='InternetUsers',y='BirthRate', fit_reg=False)
plt.show()

# %%
vis7=sns.lmplot(data=df,x='InternetUsers',y='BirthRate', fit_reg=True)
plt.show()

# %%
vis8=sns.lmplot(data=df,x='InternetUsers',y='BirthRate', fit_reg=False,hue='IncomeGroup')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 vis8=sns.lmplot(data=df,x='InternetUsers',y='BirthRate', fit_reg=False,hue='InternetGroup')
#
# File ~\anaconda\Lib\site-packages\seaborn\regression.py:611, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     609 need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     610 cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 611 data = data[cols]
#     613 # Initialize the grid
#     614 facets = FacetGrid(
#     615     data, row=row, col=col, hue=hue,
# ...
